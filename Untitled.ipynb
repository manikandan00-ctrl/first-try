# %%
import numpy as np   
arr=np.array([5,6,7])
print("sum:",np.sum(arr))
print("square root:",np.squareroot(arr))
print("difference:",np.difference(arr))
print("multiplication:",np.multiplicaion(arr))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 import numpy as np
#       2 arr=np.array([5,6,7])
#       3 print("sum:",np.sum(arr))
#
# File ~\numpy.py:3
#       1 import numpy as np
# ----> 3 array=np.arr([5,6,7])
#       4 print("sum:",sum([array]))
#       5 print("square root:",([array]))
#
# AttributeError: module 'numpy' has no attribute 'arr' (consider renaming 'C:\Users\Ibscai24.DGVC-MCA\numpy.py' if it has the same name as a library you intended to import)

# %%
import numpy as np   
array=np.array([5,6,7])
print("sum:",np.sum(array))
print("square root:",np.squareroot(array))
print("difference:",np.difference(array))
print("multiplication:",np.multiplicaion(array))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import numpy as np
#       2 array=np.array([5,6,7])
#       3 print("sum:",np.sum(array))
#
# File ~\numpy.py:3
#       1 import numpy as np
# ----> 3 array=np.arr([5,6,7])
#       4 print("sum:",sum([array]))
#       5 print("square root:",([array]))
#
# AttributeError: module 'numpy' has no attribute 'arr' (consider renaming 'C:\Users\Ibscai24.DGVC-MCA\numpy.py' if it has the same name as a library you intended to import)
